# %%
import pandas as pd 

value = list(range(5, 0, -1))
material = ["cotton", "funnel", "plastic", "vinyl", "silk"]

df = pd.DataFrame({"type": value, "material": material})


df.head()
# Out:
#    type material
# 0     5   cotton
# 1     4   funnel
# 2     3  plastic
# 3     2    vinyl
# 4     1     silk

# %% [markdown]
# ### assign new column by assigning same value like other column

# %%
df['type duplicate'] = df.type

df.head()
# Out:
#    type material  type duplicate
# 0     5   cotton               5
# 1     4   funnel               4
# 2     3  plastic               3
# 3     2    vinyl               2
# 4     1     silk               1

# %% [markdown]
# ## Notice how it doesn't work with key assignment like below

# %%
df.type2 = df.type

df.head()
# Out:
# /home/wei/miniconda3/envs/ko-auto-coding/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#    type material  type duplicate
# 0     5   cotton               5
# 1     4   funnel               4
# 2     3  plastic               3
# 3     2    vinyl               2
# 4     1     silk               1

# %%
df['random'] = -1 #np.NaN

df.head()
# Out:
#    type material  type duplicate  random
# 0     5   cotton               5      -1
# 1     4   funnel               4      -1
# 2     3  plastic               3      -1
# 3     2    vinyl               2      -1
# 4     1     silk               1      -1

# %% [markdown]
# ## works with formula based on other column as well

# %%
df['type2'] = df.type * 10

df.head()
# Out:
#    type material  type duplicate  random  type2
# 0     5   cotton               5      -1     50
# 1     4   funnel               4      -1     40
# 2     3  plastic               3      -1     30
# 3     2    vinyl               2      -1     20
# 4     1     silk               1      -1     10

# %% [markdown]
# ## work with assign numpy array as well

# %%
import numpy as np

arr = np.array([1,2,3,4,5], dtype=int)

df['array'] = arr

df.head()
# Out:
#    type material  type duplicate  random  type2  array
# 0     5   cotton               5      -1     50      1
# 1     4   funnel               4      -1     40      2
# 2     3  plastic               3      -1     30      3
# 3     2    vinyl               2      -1     20      4
# 4     1     silk               1      -1     10      5

# %% [markdown]
# ## works with native list

# %%
df['from_list'] = list(range(100, 105, 1))


df.head()
# Out:
#    type material  type duplicate  random  type2  array  from_list
# 0     5   cotton               5      -1     50      1        100
# 1     4   funnel               4      -1     40      2        101
# 2     3  plastic               3      -1     30      3        102
# 3     2    vinyl               2      -1     20      4        103
# 4     1     silk               1      -1     10      5        104
