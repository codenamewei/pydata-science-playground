# %%
import pandas as pd

# %%
pd.read_csv("data/test_outscope.csv", delimiter = '\x01')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-e8b26cc32bdb> in <module>
# ----> 1 pd.read_csv("data/test_outscope.csv", delimiter = '\x01')
#
# ~\.conda\envs\data-science-playground\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
pd.read_csv("data/bad_lines.csv", delimiter = '\x01', error_bad_lines = False)
# Out:
# b'Skipping line 5: expected 13 fields, saw 15\n'
#     F_NAN_KEY   CAT_CODE              CAT_LONG  BRAND_CODE BRAND_LONG  \
# 0  69000000.0  160988025        (E)DINNER WARE   161283384   THE CHEF
# 1  59080000.0  160988023  (E)HEALTH FUNCTIONAL   102758695    DENMARK
# 2  59080000.0  160988023  (E)HEALTH FUNCTIONAL   102758695    DENMARK
# 3  59080000.0  160988023  (E)HEALTH FUNCTIONAL   102758695    DENMARK
# 4  59080000.0  160988023  (E)HEALTH FUNCTIONAL   102758695    DENMARK
#
#    MANUFACTURER_CODE       MANUFACTURER     PROD_ID  \
# 0          102371119  HANKOOK CHINAWARE    42196398
# 1          103291997        DONGWON F&B  6501517521
# 2          103291997        DONGWON F&B   670131436
# 3          103291997        DONGWON F&B  6501517521
# 4          103291997        DONGWON F&B   670131436
#
#   F_XCI_EXTERNAL_CODE_SUFFIX SOURCEID            PROD_DESC_RAW  \
# 0                        D:1    KR250           더셰프 4인 홈세트 20p
# ...
