# %%
import pandas as pd

df = pd.read_csv("data/sample.csv")

# %% [markdown]
# # head

# %%
df.head(5)
# Out:
#    Unnamed: 0   country  price           province             region_1  \
# 0           0     Italy    NaN  Sicily & Sardinia                 Etna
# 1           1  Portugal   15.0              Douro                  NaN
# 2           2        US   14.0             Oregon    Willamette Valley
# 3           3        US   13.0           Michigan  Lake Michigan Shore
# 4           4        US   65.0             Oregon    Willamette Valley
#
#           variety
# 0     White Blend
# 1  Portuguese Red
# 2      Pinot Gris
# 3        Riesling
# 4      Pinot Noir

# %% [markdown]
# # tail

# %%
df.tail(5)
# Out:
#     Unnamed: 0 country  price           province               region_1  \
# 25          25      US   69.0         California           Sonoma Coast
# 26          26   Italy   13.0  Sicily & Sardinia        Terre Siciliane
# 27          27   Italy   10.0  Sicily & Sardinia        Terre Siciliane
# 28          28   Italy   17.0  Sicily & Sardinia  Cerasuolo di Vittoria
# 29          29      US   16.0         California             Clarksburg
#
#          variety
# 25    Pinot Noir
# 26   White Blend
# 27  Nero d'Avola
# 28     Red Blend
# 29  Chenin Blanc

# %% [markdown]
# # sample

# %%
df.sample(5)
# Out:
#    Unnamed: 0   country  price        province             region_1  \
# 1           1  Portugal   15.0           Douro                  NaN
# 5           5     Spain   15.0  Northern Spain              Navarra
# 9           9    France   27.0          Alsace               Alsace
# 3           3        US   13.0        Michigan  Lake Michigan Shore
# 4           4        US   65.0          Oregon    Willamette Valley
#
#               variety
# 1      Portuguese Red
# 5  Tempranillo-Merlot
# 9          Pinot Gris
# 3            Riesling
# 4          Pinot Noir
